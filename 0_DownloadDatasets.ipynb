# %% [markdown]
# # Download Datasets

# %%
# !mkdir dataset
# !mkdir results
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/14 -P dataset # dichasus-cf02
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/15 -P dataset # dichasus-cf03
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/16 -P dataset # dichasus-cf04

# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf02.json -P dataset
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf03.json -P dataset
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf04.json -P dataset

# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/19 -P dataset # spec.json
# Out:
# --2025-08-11 10:00:41--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/14
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5699d7-94a3d3279f39?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf02.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T100042Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=211efe2c539a501e3ccbe0651c497a6d5858dacf23edce648dbe7d50e737e19e [following]
# --2025-08-11 10:00:42--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5699d7-94a3d3279f39?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf02.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T100042Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=211efe2c539a501e3ccbe0651c497a6d5858dacf23edce648dbe7d50e737e19e
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.99, 129.69.5.100, 2001:7c0:2041:1db::100, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4885294444 (4.5G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf02.tfrecords’
#
# dichasus-cf02.tfrec 100%[===================>]   4.55G  23.5MB/s    in 3m 39s
#
# 2025-08-11 10:04:21 (21.3 MB/s) - ‘dataset/dichasus-cf02.tfrecords’ saved [4885294444/4885294444]
#
# --2025-08-11 10:04:21--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/15
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5826ef-29891f50dfba?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf03.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T100421Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=5e034be12109ed3e177b3a2cdc03609817018a1c23b1c189780ab29c6b224d2d [following]
# --2025-08-11 10:04:21--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5826ef-29891f50dfba?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf03.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T100421Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=5e034be12109ed3e177b3a2cdc03609817018a1c23b1c189780ab29c6b224d2d
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.100, 129.69.5.99, 2001:7c0:2041:1db::99, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5946549946 (5.5G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf03.tfrecords’
#
# dichasus-cf03.tfrec 100%[===================>]   5.54G  29.3MB/s    in 3m 31s
#
# 2025-08-11 10:07:52 (26.9 MB/s) - ‘dataset/dichasus-cf03.tfrecords’ saved [5946549946/5946549946]
#
# --2025-08-11 10:07:53--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/16
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5b6fc0-63757420b35e?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf04.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T100753Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=d065f92034f695d7a784070c8e1ede196372566164343cac40d83f2396449341 [following]
# --2025-08-11 10:07:53--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5b6fc0-63757420b35e?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf04.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T100753Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=d065f92034f695d7a784070c8e1ede196372566164343cac40d83f2396449341
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.100, 129.69.5.99, 2001:7c0:2041:1db::100, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11071618276 (10G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf04.tfrecords’
#
# dichasus-cf04.tfrec 100%[===================>]  10.31G  15.0MB/s    in 9m 3s
#
# 2025-08-11 10:16:58 (19.4 MB/s) - ‘dataset/dichasus-cf04.tfrecords’ saved [11071618276/11071618276]
#
# --2025-08-11 10:16:58--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf02.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1833 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf02.json’
#
# reftx-offsets-dicha 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2025-08-11 10:16:58 (133 MB/s) - ‘dataset/reftx-offsets-dichasus-cf02.json’ saved [1833/1833]
#
# --2025-08-11 10:16:58--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf03.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1834 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf03.json’
#
# reftx-offsets-dicha 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2025-08-11 10:16:58 (219 MB/s) - ‘dataset/reftx-offsets-dichasus-cf03.json’ saved [1834/1834]
#
# --2025-08-11 10:16:58--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf04.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1841 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf04.json’
#
# reftx-offsets-dicha 100%[===================>]   1.80K  --.-KB/s    in 0s
#
# 2025-08-11 10:16:58 (178 MB/s) - ‘dataset/reftx-offsets-dichasus-cf04.json’ saved [1841/1841]
#
# --2025-08-11 10:16:58--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/19
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ed2590b69-8674fc020773?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27spec.json&response-content-type=application%2Fjson&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T101659Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=07398045bb92d62d2ea4ddf1a76a5b6a833c47fcf628ca5b2c4e84c71b0394d3 [following]
# --2025-08-11 10:16:59--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ed2590b69-8674fc020773?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27spec.json&response-content-type=application%2Fjson&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250811T101659Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250811%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=07398045bb92d62d2ea4ddf1a76a5b6a833c47fcf628ca5b2c4e84c71b0394d3
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.99, 129.69.5.100, 2001:7c0:2041:1db::100, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4231 (4.1K) [application/json]
# Saving to: ‘dataset/spec.json’
#
# spec.json           100%[===================>]   4.13K  --.-KB/s    in 0s
#
# 2025-08-11 10:16:59 (1.15 GB/s) - ‘dataset/spec.json’ saved [4231/4231]
